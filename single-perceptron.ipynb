# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
def plot_datasets_subplots(X_train, Y_train, X_val, Y_val, X_test, Y_test):
    fig, axs = plt.subplots(1, 3, figsize=(18, 5))

    def scatter_plot(ax, X, Y, title):
        group_a = X[Y == 1]
        group_b = X[Y == 0]
        ax.scatter(group_a[:, 0], group_a[:, 1], color='blue', label='Group A')
        ax.scatter(group_b[:, 0], group_b[:, 1], color='red', label='Group B')
        ax.set_title(title)
        ax.set_xlabel("X-axis")
        ax.set_ylabel("Y-axis")
        ax.legend()
        ax.grid(True)

    scatter_plot(axs[0], X_train, Y_train, "Training Data")
    scatter_plot(axs[1], X_val, Y_val, "Validation Data")
    scatter_plot(axs[2], X_test, Y_test, "Test Data")

    plt.tight_layout()
    plt.show()

# Parameters
N_train = 500
N_test = 200
N_val = 200  # Validation set size
mean_a, mean_b = 5, 16

# Raw data (total = N_train*2 + N_val*2 + N_test*2 = 1800 samples)
total_per_class = N_train + N_val + N_test

# Generate raw data per class
group_a = [[rd.gauss(mean_a, 3), rd.gauss(mean_a, 3)] for _ in range(total_per_class)]
group_b = [[rd.gauss(mean_b, 3), rd.gauss(mean_b, 3)] for _ in range(total_per_class)]

X_raw_data = np.array(group_a + group_b)
Y_raw_data = np.array([1] * total_per_class + [0] * total_per_class)

# Shuffle the dataset (optional but recommended before splitting)
indices = np.arange(len(X_raw_data))
np.random.shuffle(indices)
X_raw_data = X_raw_data[indices]
Y_raw_data = Y_raw_data[indices]

# Manual split (total = 1800: 1000 train, 400 val, 400 test)
train_size = 2 * N_train
val_size = 2 * N_val
test_size = 2 * N_test

X_train = X_raw_data[:train_size]
Y_train = Y_raw_data[:train_size]

X_val = X_raw_data[train_size:train_size + val_size]
Y_val = Y_raw_data[train_size:train_size + val_size]


X_test = X_raw_data[train_size + val_size:]
Y_test = Y_raw_data[train_size + val_size:]

# Normalization based on train set
min_val = np.min(X_raw_data)
max_val = np.max(X_raw_data)

X_train = (X_train - min_val) / (max_val - min_val)
X_val = (X_val - min_val) / (max_val - min_val)
X_test = (X_test - min_val) / (max_val - min_val)


# Call the function after preparing and normalizing your data
plot_datasets_subplots(X_train, Y_train, X_val, Y_val, X_test, Y_test)

# %%
modele = Sequential()

p = 1
# Première couche : p neurones (entrée de dimension 2)
modele.add(Dense(p, input_dim=2, activation="sigmoid"))


# Choix de la méthode de descente de gradient
modele.compile(loss="binary_crossentropy", optimizer="sgd", metrics=["accuracy"])
print(modele.summary())


### Partie C - Calcul des poids par descente de gradient
modele.fit(X_train, Y_train, batch_size=20, epochs=50)


### Partie D - Résultats
resultat = modele.evaluate(X_val, Y_val, verbose=0)
print("Valeur de l'erreur sur les données de test (loss):", resultat[0])
print("Précision sur les données de test (accuracy):", resultat[1])
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3 (12.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5022 - loss: 0.6538
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5397 - loss: 0.6383
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5118 - loss: 0.6456
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5466 - loss: 0.6349
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5922 - loss: 0.6274
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6005 - loss: 0.6238
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6124 - loss: 0.6233
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6363 - loss: 0.6144
# Epoch 9/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6536 - loss: 0.6150
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6668 - loss: 0.6155
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7070 - loss: 0.6079
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7391 - loss: 0.5997
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7579 - loss: 0.5922
# Epoch 14/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7791 - loss: 0.5911
# Epoch 15/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8020 - loss: 0.5917
# Epoch 16/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8120 - loss: 0.5896
# Epoch 17/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8148 - loss: 0.5856
# Epoch 18/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8510 - loss: 0.5786
# Epoch 19/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8547 - loss: 0.5758
# Epoch 20/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8725 - loss: 0.5671
# Epoch 21/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8672 - loss: 0.5690
# Epoch 22/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8749 - loss: 0.5621
# Epoch 23/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8876 - loss: 0.5575
# Epoch 24/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9002 - loss: 0.5582
# Epoch 25/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9067 - loss: 0.5537
# Epoch 26/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8941 - loss: 0.5539
# Epoch 27/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9245 - loss: 0.5445
# Epoch 28/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9208 - loss: 0.5418
# Epoch 29/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9314 - loss: 0.5391
# Epoch 30/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9299 - loss: 0.5401
# Epoch 31/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9291 - loss: 0.5352
# Epoch 32/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9374 - loss: 0.5318
# Epoch 33/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9419 - loss: 0.5260
# Epoch 34/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9450 - loss: 0.5212
# Epoch 35/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9437 - loss: 0.5183
# Epoch 36/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9486 - loss: 0.5188
# Epoch 37/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9560 - loss: 0.5151
# Epoch 38/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9538 - loss: 0.5114
# Epoch 39/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9440 - loss: 0.5099
# Epoch 40/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9520 - loss: 0.5082
# Epoch 41/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9734 - loss: 0.5016
# Epoch 42/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9570 - loss: 0.4989
# Epoch 43/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9698 - loss: 0.4965
# Epoch 44/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9641 - loss: 0.4933
# Epoch 45/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9576 - loss: 0.4948
# Epoch 46/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ -1s -14110us/step - accuracy: 0.9704 - loss: 0.4877
# Epoch 47/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9585 - loss: 0.4849
# Epoch 48/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9712 - loss: 0.4802
# Epoch 49/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9779 - loss: 0.4822
# Epoch 50/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9699 - loss: 0.4813
# Valeur de l'erreur sur les données de test (loss): 0.4813328683376312
# Précision sur les données de test (accuracy): 0.9624999761581421

# %%
# --- Partie E - Prédictions ---

# Prédictions sur X_test (normalisé)
Y_predict_proba = modele.predict(X_test)
Y_predict = [1 if y[0] >= 0.5 else 0 for y in Y_predict_proba]

# Dénormalisation de X_val pour affichage
X_test_denorm = (X_test * (max_val - min_val)) + min_val

# Tracé des points prédits
plt.figure(figsize=(6, 6))
blue = []
red = []
for i in range(len(X_test_denorm)):
    if Y_predict[i] == 1:
        blue.append((X_test_denorm[i][0], X_test_denorm[i][1]))
    else:
        red.append((X_test_denorm[i][0], X_test_denorm[i][1]))

blue = np.array(blue)
red = np.array(red)

if len(blue) > 0:
    plt.scatter(blue[:, 0], blue[:, 1], color='blue', label='Group A')
if len(red) > 0:
    plt.scatter(red[:, 0], red[:, 1], color='red', label='Group B')

# --- Tracé de la frontière de décision (linéaire) ---
weights = modele.get_weights()
w1, w2 = weights[0][0][0], weights[0][1][0]
b = weights[1][0]

# Calcul de la frontière de décision dans l'espace normalisé
x_vals_norm = np.linspace(0, 1, 100)
y_vals_norm = -(w1 / w2) * x_vals_norm - b / w2

# Dénormalisation
x_vals = x_vals_norm * (max_val - min_val) + min_val
y_vals = y_vals_norm * (max_val - min_val) + min_val

# Limites du graphique basées sur les données
x_min, x_max = np.min(X_test_denorm[:, 0]), np.max(X_test_denorm[:, 0])
y_min, y_max = np.min(X_test_denorm[:, 1]), np.max(X_test_denorm[:, 1])
plt.xlim(x_min - 1, x_max + 1)
plt.ylim(y_min - 1, y_max + 1)

# Tracé de la frontière
plt.plot(x_vals, y_vals, color="black", linestyle="--", label="Decision Boundary")

plt.title("Prédictions et frontière de décision (Test Set)")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
